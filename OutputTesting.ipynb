# %%
import h5py
import numpy as np
from tenpy.tools.hdf5_io import load, load_from_hdf5
#import LangGraphExperiments
#import NQSExperiments

for i in range(5):
    j = i
    h5_filepath = f"data_outputs/wavefunctions/three_site_kagome_{j:03d}.h5"
    print("File name: ", h5_filepath)
    with h5py.File(h5_filepath, 'r+') as f_h5:
        
        #psi = load_from_hdf5(f_h5, 'psi')
        print("f_h5 keys: ", list(f_h5.keys()))
    
        keys = list(f_h5['model_params'].keys())
        print(f"f_h5['model_params'] (input) Keys: {keys}")
        #for key in keys:
        #    print(f"{key} : {f_h5['model_params'][key][()]}")
        #print()
        keys = list(f_h5['observables'].keys())
        print(f"f_h5['observables'] (output) keys: {keys}")
        #for key in keys:
        #    print(f"{key} : {f_h5['observables'][key][:]}")
        #print()
        obs = f_h5['observables']
        spin_corr = obs['spin_corr'][:]
        print("spin correlation matrix:\n", spin_corr)
        energy = f_h5['energy'][()]
        print(f"energy: \n{energy}")
# Out:
# File name:  data_outputs/wavefunctions/three_site_kagome_000.h5
# f_h5 keys:  ['average_energy', 'average_observables', 'energy', 'model_params', 'observables', 'psi']
# f_h5['model_params'] (input) Keys: ['Lx', 'Ly', 'N_elec', 'U', 'bc_x', 'bc_y', 'cons_N', 'cons_Sz', 'explicit_plus_hc', 'mu', 'sort_mpo_legs', 't1', 't2', 'theta_x', 'theta_y']
# f_h5['observables'] (output) keys: ['S_q_charge', 'S_q_spin', 'charge_corr', 'charge_density', 'double_occupancy', 'q_vectors', 'spin_corr']
# spin correlation matrix:
#  [[0.0833337  0.         0.        ]
#  [0.         0.08333315 0.        ]
#  [0.         0.         0.08333315]]
# energy:
# -2.0000033333407408
# File name:  data_outputs/wavefunctions/three_site_kagome_001.h5
# f_h5 keys:  ['average_energy', 'average_observables', 'energy', 'model_params', 'observables', 'psi']
# f_h5['model_params'] (input) Keys: ['Lx', 'Ly', 'N_elec', 'U', 'bc_x', 'bc_y', 'cons_N', 'cons_Sz', 'explicit_plus_hc', 'mu', 'sort_mpo_legs', 't1', 't2', 'theta_x', 'theta_y']
# f_h5['observables'] (output) keys: ['S_q_charge', 'S_q_spin', 'charge_corr', 'charge_density', 'double_occupancy', 'q_vectors', 'spin_corr']
# spin correlation matrix:
#  [[ 0.11902032 -0.05951016 -0.05951016]
#  [-0.05951016  0.11901994 -0.05950978]
#  [-0.05951016 -0.05950978  0.11901994]]
# energy:
# -3.7895856452324
# File name:  data_outputs/wavefunctions/three_site_kagome_002.h5
# f_h5 keys:  ['average_energy', 'average_observables', 'energy', 'model_params', 'observables', 'psi']
# f_h5['model_params'] (input) Keys: ['Lx', 'Ly', 'N_elec', 'U', 'bc_x', 'bc_y', 'cons_N', 'cons_Sz', 'explicit_plus_hc', 'mu', 'sort_mpo_legs', 't1', 't2', 'theta_x', 'theta_y']
# f_h5['observables'] (output) keys: ['S_q_charge', 'S_q_spin', 'charge_corr', 'charge_density', 'double_occupancy', 'q_vectors', 'spin_corr']
# spin correlation matrix:
#  [[ 0.14021727 -0.07010863 -0.07010863]
#  [-0.07010863  0.14021684 -0.07010821]
#  [-0.07010863 -0.07010821  0.14021684]]
# energy:
# -3.228449427605271
# File name:  data_outputs/wavefunctions/three_site_kagome_003.h5
# f_h5 keys:  ['average_energy', 'average_observables', 'energy', 'model_params', 'observables', 'psi']
# f_h5['model_params'] (input) Keys: ['Lx', 'Ly', 'N_elec', 'U', 'bc_x', 'bc_y', 'cons_N', 'cons_Sz', 'explicit_plus_hc', 'mu', 'sort_mpo_legs', 't1', 't2', 'theta_x', 'theta_y']
# f_h5['observables'] (output) keys: ['S_q_charge', 'S_q_spin', 'charge_corr', 'charge_density', 'double_occupancy', 'q_vectors', 'spin_corr']
# spin correlation matrix:
#  [[0.0833337  0.         0.        ]
#  [0.         0.08333315 0.        ]
#  [0.         0.         0.08333315]]
# energy:
# -2.0000033333407408
# File name:  data_outputs/wavefunctions/three_site_kagome_004.h5
# f_h5 keys:  ['average_energy', 'average_observables', 'energy', 'model_params', 'observables', 'psi']
# f_h5['model_params'] (input) Keys: ['Lx', 'Ly', 'N_elec', 'U', 'bc_x', 'bc_y', 'cons_N', 'cons_Sz', 'explicit_plus_hc', 'mu', 'sort_mpo_legs', 't1', 't2', 'theta_x', 'theta_y']
# f_h5['observables'] (output) keys: ['S_q_charge', 'S_q_spin', 'charge_corr', 'charge_density', 'double_occupancy', 'q_vectors', 'spin_corr']
# spin correlation matrix:
#  [[ 0.1666663  -0.08333315 -0.08333315]
#  [-0.08333315  0.16666685 -0.0833337 ]
#  [-0.08333315 -0.0833337   0.16666685]]
# energy:
# -0.0039027466899194843
